# %% [markdown]
# # Introduction
#
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# # Project Name - Electric Vehicle Population
#
# **_By-Munshi Fazal and Mehsar Alam_**
#
# # Problem Statement
#
# The primary objective of this Data Visualisation is to gain a comprehensive understanding of the electric vehicle market.
#
# # Objective
#
# **1. Identify Market Trends:** Understand the current trends and patterns in electric vehicle adoption,and comparition between Battery Electric Vehicle and Plug-in Hybrid Electric Vehicle such as the growing popularity of BEVs and PHEVs. and the increasing focus on longer range vehicles.
#
# **2. Assess Market Dynamics:** Analyze the factors influencing the electric vehicle market, including consumer preferences, technological advancements, government policies, and infrastructure development.
#
# **3. Evaluate Policy Impact:** Assess the effectiveness of government policies, such as CAFV incentives, in promoting electric vehicle adoption.
#
# **4. Identify Opportunities and Challenges:** Identify potential opportunities and challenges for the electric vehicle industry, such as the need for improved charging infrastructure or the development of new battery technologies.

# %% [markdown]
# # Github Link
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# https://github.com/Ansari-Mehsar/Anudip-Lab-Solution/blob/main/Sprint%201.rar

# %% [markdown]
# # Import neccessary packages
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# **Insight**
# Import all necessary packages

# %% [markdown]
# # Loading the file from the Local System to the Notebook
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
#importing pandas library
import pandas as pd
# Reading csv file from the system
# Use read_csv to read the data from the CSV file into a DataFrame
data_df = pd.read_csv(r'C:\Users\Mehshar\Desktop\Sprint 1\Electric_Vehicle_Population_Data.csv')

data_df
# Out:
#         VIN (1-10)        County       City State  Postal Code  Model Year  \
# 0       5YJSA1E22K          King    Seattle    WA      98112.0        2019
# 1       3MW39FS05R        Yakima     Zillah    WA      98953.0        2024
# 2       1N4AZ0CP0F          King       Kent    WA      98031.0        2015
# 3       5YJSA1H20F     Snohomish    Bothell    WA      98012.0        2015
# 4       JTMAB3FV1N        Yakima     Yakima    WA      98908.0        2022
# ...            ...           ...        ...   ...          ...         ...
# 191402  5YJ3E1EA0K        Pierce     Sumner    WA      98390.0        2019
# 191403  JN1BF0BA7P        Pierce   Wilkeson    WA      98396.0        2023
# 191404  7SAYGDEE4R          King  Fall City    WA      98024.0        2024
# 191405  7SAXCBE65N  Grays Harbor   Aberdeen    WA      98520.0        2022
# 191406  7SAYGAEEXP        Benton   Richland    WA      99352.0        2023
#
# ...

# %% [markdown]
# **Insight**
# Loading the file from local system to jupyter notebook

# %%
data_df.shape
# Out:
# (191407, 17)

# %% [markdown]
# **Insight**
# Here we print row and column size of the dataset

# %% [markdown]
# # _Dataset view_
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
# Display the first 5 rows of the DataFrame
data_df.head()
# Out:
#    VIN (1-10)     County     City State  Postal Code  Model Year    Make  \
# 0  5YJSA1E22K       King  Seattle    WA      98112.0        2019   TESLA
# 1  3MW39FS05R     Yakima   Zillah    WA      98953.0        2024     BMW
# 2  1N4AZ0CP0F       King     Kent    WA      98031.0        2015  NISSAN
# 3  5YJSA1H20F  Snohomish  Bothell    WA      98012.0        2015   TESLA
# 4  JTMAB3FV1N     Yakima   Yakima    WA      98908.0        2022  TOYOTA
#
#         Model                   Electric Vehicle Type  \
# 0     MODEL S          Battery Electric Vehicle (BEV)
# 1        330E  Plug-in Hybrid Electric Vehicle (PHEV)
# 2        LEAF          Battery Electric Vehicle (BEV)
# 3     MODEL S          Battery Electric Vehicle (BEV)
# 4  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             270
# ...

# %% [markdown]
# **Insight**
# Here we print the first five rows of the dataset

# %%
# Display the last 5 rows of the dataframe
data_df.tail()
# Out:
#         VIN (1-10)        County       City State  Postal Code  Model Year  \
# 191402  5YJ3E1EA0K        Pierce     Sumner    WA      98390.0        2019
# 191403  JN1BF0BA7P        Pierce   Wilkeson    WA      98396.0        2023
# 191404  7SAYGDEE4R          King  Fall City    WA      98024.0        2024
# 191405  7SAXCBE65N  Grays Harbor   Aberdeen    WA      98520.0        2022
# 191406  7SAYGAEEXP        Benton   Richland    WA      99352.0        2023
#
#           Make    Model           Electric Vehicle Type  \
# 191402   TESLA  MODEL 3  Battery Electric Vehicle (BEV)
# 191403  NISSAN    ARIYA  Battery Electric Vehicle (BEV)
# 191404   TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 191405   TESLA  MODEL X  Battery Electric Vehicle (BEV)
# 191406   TESLA  MODEL Y  Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 191402            Clean Alternative Fuel Vehicle Eligible             220
# ...

# %% [markdown]
# **Insight**
# Here we print the last five rows of the dataset

# %%
# To print the column names present in the dataset.
data_df.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %% [markdown]
# **Insight**
# Print the columns name present in the dataset

# %% [markdown]
# # UNDERSTANDING THE VARIABLE
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# **1. VIN (1-10):**
# Vehicle Identification Number (VIN): A unique code assigned to each vehicle for identification. In this case, it represents the first 10 characters of the full VIN. It helps track a specific vehicle's make, model, year, and origin.
# **2. County:**
# The administrative region (within a state) where the electric vehicle is registered or located. It helps in analyzing the geographic distribution of EVs at the county level.
# **3. City:**
# The city where the vehicle is registered or in use. It allows for detailed geographic analysis and helps determine urban versus rural EV adoption trends.
# **4. State:**
# The state in which the vehicle is registered. This helps in regional analysis of EV adoption across different states in the country.
# **5. Postal Code:**
# The ZIP code where the vehicle is registered. It provides even more granular geographic detail, enabling neighborhood-level insights.
# **6. Model Year:**
# The year in which the vehicle was manufactured. This column helps in tracking how the electric vehicle market has evolved over time and allows for analyzing trends in vehicle adoption by age.
# **7. Make:**
# **The brand or manufacturer of the vehicle (e.g., Tesla, Nissan, Chevrolet). This column is important for analyzing the market share of different manufacturers.
# **8. Model:\*\*
# **The specific model of the vehicle (e.g., Tesla Model 3, Nissan Leaf). It helps in understanding which models are more popular and comparing their performance or market adoption.
# **9. Electric Vehicle Type:**
# The type of electric vehicle, such as:
# Battery Electric Vehicle (BEV): Fully electric, with no internal combustion engine.
# Plug-in Hybrid Electric Vehicle (PHEV): Hybrid vehicle with an internal combustion engine and a battery that can be charged. This column allows you to differentiate between different categories of electric vehicles.
# **10. Clean Alternative Fuel Vehicle (CAFV) Eligibility:**
# Indicates whether the vehicle is eligible for government incentives or policies designed to promote cleaner transportation (e.g., tax rebates, subsidies). This field helps assess how policy incentives affect vehicle adoption.
# **11. Electric Range:**
# The maximum distance the vehicle can travel on a full charge (in miles or kilometers). It helps in evaluating the performance of different EV models and correlating it with consumer preferences.
# **12. Base MSRP:**
# Manufacturer’s Suggested Retail Price: The price at which the vehicle is sold before any discounts, rebates, or incentives. It provides insight into the economic factors influencing EV adoption and affordability.
# **13. Legislative District:**
# The political district where the vehicle is registered. This is useful for analyzing the impact of regional policies and political decisions on EV adoption rates.
# **14. DOL Vehicle ID:**
# The unique identifier assigned to the vehicle by the Department of Licensing. This is another unique identifier that may be useful for tracking vehicles or performing vehicle-level analysis.
# **15. Vehicle Location:**
# The geographic coordinates or location of the vehicle. This column helps in spatial analysis, such as proximity to charging stations or utility service areas.
# **16. Electric Utility:**
# The utility company that provides electricity to the vehicle's location. This is relevant for analyzing how different utility companies support EV charging infrastructure and services.
# **17. 2020 Census Tract:\*\*
# A small, relatively permanent statistical subdivision of a county used by the U.S. Census Bureau. It helps in understanding the demographic characteristics (income, population density, etc.) of areas where EVs are adopted.

# %% [markdown]
# # Dataset Information
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
#Dataset information and no of columns along with the data types of their values
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191407 entries, 0 to 191406
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         191407 non-null  object
#  1   County                                             191403 non-null  object
#  2   City                                               191403 non-null  object
#  3   State                                              191407 non-null  object
#  4   Postal Code                                        191403 non-null  float64
#  5   Model Year                                         191407 non-null  int64
#  6   Make                                               191407 non-null  object
#  7   Model                                              191407 non-null  object
# ...

# %% [markdown]
# **Insight**
# we use info() to get the summary of our dataset i.e column, non null, count, memory, usage and datset

# %% [markdown]
# # **Data Cleaning**
#
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
#The describe() function in the Pandas library provides a quick overview of the statistical properties of a DataFrame or Series.
data_df.describe()
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  191403.000000  191407.000000   191407.000000  191407.000000
# mean    98177.823603    2020.732335       55.657442     994.773258
# std      2392.808886       2.990487       90.151930    8050.523372
# min      1731.000000    1997.000000        0.000000       0.000000
# 25%     98052.000000    2019.000000        0.000000       0.000000
# 50%     98125.000000    2022.000000        0.000000       0.000000
# 75%     98371.000000    2023.000000       72.000000       0.000000
# max     99577.000000    2025.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         190993.000000    1.914070e+05       1.914030e+05
# mean              29.016880    2.237202e+08       5.297759e+10
# std               14.909417    7.398058e+07       1.573588e+09
# min                1.000000    4.385000e+03       1.001020e+09
# ...

# %%
# The value_counts() function in Pandas is used to count the occurrences of unique values in a Pandas Series or DataFrame column.
data_df['County'].value_counts(ascending=True)
# Out:
# County
# Richland            1
# Goochland           1
# Lee                 1
# Newport News        1
# Hennepin            1
#                 ...
# Thurston         6969
# Clark           11335
# Pierce          14932
# Snohomish       22643
# King            99076
# Name: count, Length: 197, dtype: int64

# %% [markdown]
# # Missing values/Null values

# %%
#To determine count of NaN values in the column
data_df.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 4
# City                                                   4
# State                                                  0
# Postal Code                                            4
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 414
# DOL Vehicle ID                                         0
# Vehicle Location                                       8
# Electric Utility                                       4
# ...

# %% [markdown]
# **Insight**
# Here we used isnull().sum() to identify and count missing values (NaNs) in a DataFrame

# %%
'''The dropna() function in Pandas is used to remove missing or NaN (Not-a-Number)
values from a DataFrame or Series. It allows you to clean our data by eliminating rows
or columns that contain missing values.'''
data_df.dropna(inplace=True)
print("after removing NaN values:")
data_df.info()
# Out:
# after removing NaN values:
# <class 'pandas.core.frame.DataFrame'>
# Index: 190989 entries, 0 to 191406
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         190989 non-null  object
#  1   County                                             190989 non-null  object
#  2   City                                               190989 non-null  object
#  3   State                                              190989 non-null  object
#  4   Postal Code                                        190989 non-null  float64
#  5   Model Year                                         190989 non-null  int64
#  6   Make                                               190989 non-null  object
#  7   Model                                              190989 non-null  object
# ...

# %% [markdown]
# # _Duplicate Values_

# %%
#The duplicated() function in Pandas is used to identify and mark duplicated rows in a DataFrame or Series.
data_df.duplicated(subset=None, keep='first')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 191402    False
# 191403    False
# 191404    False
# 191405    False
# 191406    False
# Length: 190989, dtype: bool

# %%
# To find no.of duplicate rows in the dataframe
duplicate_rows = data_df.duplicated()
print("Number of duplicate rows:", duplicate_rows.sum())
# Out:
# Number of duplicate rows: 0

# %%
#Before removing checking no of row and col
print("After removing NaN values")
print(data_df.shape)
# Out:
# After removing NaN values
# (190989, 17)

# %% [markdown]
# # _Check Unique Values for each variable_

# %%
# Check Unique Values for each variable.
pd.Series({col:data_df[col].unique() for col in data_df})
# Out:
# VIN (1-10)                                           [5YJSA1E22K, 3MW39FS05R, 1N4AZ0CP0F, 5YJSA1H20...
# County                                               [King, Yakima, Snohomish, Thurston, Kitsap, Wh...
# City                                                 [Seattle, Zillah, Kent, Bothell, Yakima, Redmo...
# State                                                                                             [WA]
# Postal Code                                          [98112.0, 98953.0, 98031.0, 98012.0, 98908.0, ...
# Model Year                                           [2019, 2024, 2015, 2022, 2018, 2013, 2017, 202...
# Make                                                 [TESLA, BMW, NISSAN, TOYOTA, FORD, FIAT, CHRYS...
# Model                                                [MODEL S, 330E, LEAF, RAV4 PRIME, MODEL 3, FUS...
# Electric Vehicle Type                                [Battery Electric Vehicle (BEV), Plug-in Hybri...
# ...

# %% [markdown]
# **Insight**
# Here we checked all unique values from our dataframe

# %%
# Gives the overall info of the dataframe object
data_df.describe()
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  190989.000000  190989.000000   190989.000000  190989.000000
# mean    98262.698742    2020.733529       55.630335     993.899832
# std       305.327672       2.990753       90.128825    8047.355590
# min     98001.000000    1997.000000        0.000000       0.000000
# 25%     98052.000000    2019.000000        0.000000       0.000000
# 50%     98125.000000    2022.000000        0.000000       0.000000
# 75%     98372.000000    2023.000000       72.000000       0.000000
# max     99403.000000    2025.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         190989.000000    1.909890e+05       1.909890e+05
# mean              29.017090    2.237421e+08       5.303985e+10
# std               14.909503    7.398037e+07       1.626802e+07
# min                1.000000    4.385000e+03       5.300195e+10
# ...

# %% [markdown]
# **Insight**
# The provided table summarizes the descriptive statistics of a dataset related to electric vehicles. Here are some key insights:
#
# Count:
#
# The dataset contains 190,989 observations for each column.
# Mean:
#
# The average postal code is 98262.
# The average model year is 2020.
# The average electric range is 55.630335 units (likely miles).
# The average base MSRP is $993.899832.

# %%
data_df.describe(include = 'O').T
# Out:
#                                                     count unique  \
# VIN (1-10)                                         190989  11480
# County                                             190989     39
# City                                               190989    477
# State                                              190989      1
# Make                                               190989     42
# Model                                              190989    147
# Electric Vehicle Type                              190989      2
# Clean Alternative Fuel Vehicle (CAFV) Eligibility  190989      3
# Vehicle Location                                   190989    552
# Electric Utility                                   190989     74
#
#                                                                                                  top  \
# VIN (1-10)                                                                                7SAYGDEE6P
# ...

# %% [markdown]
# **Insight**
# In previous describe() we got only numeric values so get string value we used describe(include = 'O').T
# In output we can see non-numeric values.

# %% [markdown]
# # **Data Visualisation**
#
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# # Chart 1: Electric Vehicle Adoption Over the Years
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
import matplotlib.pyplot as plt

# Group the data by 'Model Year' and count the occurrences
grouped_data = data_df.groupby('Model Year').size()

# Create the line plot with enhanced visualization
plt.figure(figsize=(12, 6))
grouped_data.plot(kind='line', marker='o', color='green', linestyle='--')
plt.title('Electric Vehicle Adoption Over the Years')
plt.xlabel('Model Year')
plt.ylabel('Number of Electric Vehicles')
plt.grid(True)
plt.xticks(range(grouped_data.index.min(), grouped_data.index.max() + 1, 2))  # Adjust step size as needed
plt.show()

# %% [markdown]
# **Insight**
#
# 1. Before 2010 Electric vehicle adoption was minimal, likely due to limited technology and market availability.
#
# 2. Between 2010-2015 a period of growth as more manufacturers introduced electric vehicles and consumer interest began to rise.
#
# 3. Between 2015-2020 a Rapid adoption, reflecting a major shift in the market towards sustainable transportation.
#
# 4. Post-2023 Decline: The chart shows a potential peak in adoption around 2023, followed by a slight decline. This could be attributed to various factors, such as economic conditions, supply chain constraints, or changes in consumer preferences.
#
# This visualization clearly shows the exponential rise in electric vehicle adoption over the last decade and is a strong indicator of the industry's growth trajectory.

# %% [markdown]
# # Chart 2:Electric Vehicle Type
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'data_df' is your DataFrame

# Calculate value counts for 'Electric Vehicle Type'
type_counts = data_df['Electric Vehicle Type'].value_counts()

# Create the pie chart
plt.figure(figsize=(8, 6))  # Set the figure size to 10x8 inches
type_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, cmap='Set3')

# Add title
plt.title('Electric Vehicle Types Distribution', fontsize=16)

# Ensure the pie chart is a circle
plt.axis('equal')  # Equal aspect ratio ensures that pie chart is drawn as a circle.

# Show the plot
plt.tight_layout()  # Adjust layout to fit the figure size
plt.show()

# %% [markdown]
# **Insight**
# **BEV Dominance:** BEVs clearly dominate the market, accounting for 78.2% of the total electric vehicles. This indicates a strong preference for fully electric vehicles among consumers.
#
# **PHEV Market Share:** PHEVs hold a smaller market share of 21.8%. While they are still a significant portion of the market, BEVs have a much larger presence.
#
# Improvements in battery technology, charging infrastructure and government incentives might be influencing this preference., and vehicle range have made BEVs more attractive to consumers.

# %% [markdown]
# # Chart 3: Electric Vehicle Type by Model Year
#
# Model Year by Electric Vehicle Type: Compare how the Electric Vehicle Type has evolved over time using a grouped bar chart with Model Year on the x-axis and vehicle type as different bars within each group.
# Comparison: This helps in comparing the evolution of different electric vehicle types (BEV vs. PHEV) across different years.
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Set the global figure size
plt.rcParams['figure.figsize'] = (12, 8)

# Example data (replace this with your actual data)
# data_df = your_dataframe_here

# Create a crosstab
crosstab_data = pd.crosstab(data_df['Model Year'], data_df['Electric Vehicle Type'])

# Create the bar plot
crosstab_data.plot(kind='bar', stacked=False, title='Electric Vehicle Type by Model Year')

# Display the plot
plt.tight_layout()  # Adjust layout to fit the figure size
plt.show()

# %% [markdown]
# **Insight**
# **1. BEV Dominance:** BEVs have consistently dominated the market since their introduction, with a significantly higher number of units sold compared to PHEVs in most years.
#
# **2. Rapid BEV Growth:** The BEV market has experienced rapid growth, particularly in recent years. This suggests a strong consumer preference for fully electric vehicles.
#
# **3.PHEV Steady Growth:** PHEVs have shown steady growth, indicating a growing market for vehicles that combine electric and gasoline powertrains.
#
# **4.Market Shift:** The chart reveals a potential shift in the market, with PHEV growth starting to accelerate in recent years. This could be due to factors such as advancements in PHEV technology, government incentives, or changing consumer preferences.

# %% [markdown]
# # Chart 4: Electric Vehicle Type vs CAFV Eligibility
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
# Create a crosstab of Electric Vehicle Type and CAFV Eligibility
ev_cafv_crosstab = pd.crosstab(data_df['Electric Vehicle Type'], data_df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'])

# Plot a stacked bar chart
ev_cafv_crosstab.plot(kind='bar', stacked=True, figsize=(10, 6), color=['green', 'orange','red','blue','pink'])

# Add chart title and labels
plt.title('Electric Vehicle Type vs CAFV Eligibility')
plt.xlabel('Electric Vehicle Type')
plt.ylabel('Number of Vehicles')
plt.xticks(rotation=45)
plt.legend(title='CAFV Eligibility')
plt.show()

# %% [markdown]
# **Insight**
# **1. BEV Eligibility:** A significant portion of BEVs are eligible for CAFV benefits. This suggests that BEVs generally meet the criteria for CAFV incentives, likely due to their higher electric range and environmental benefits.
#
# **2. PHEV Eligibility:** PHEVs have a lower proportion of vehicles eligible for CAFV benefits compared to BEVs. This could be attributed to their lower electric range, which might not meet the minimum requirements for CAFV eligibility.
#
# **3. Eligibility Uncertainty:** A portion of PHEVs have an unknown eligibility status. This indicates that the battery range of these vehicles has not been researched or assessed for CAFV eligibility.
#
# The CAFV eligibility criteria have a significant impact on the adoption of electric vehicles.The different eligibility rates for BEVs and PHEVs might suggest different market segments. BEVs could be more attractive to consumers seeking maximum environmental benefits and government incentives, while PHEVs might appeal to those who prioritize a combination of electric and gasoline powertrains.

# %% [markdown]
# # Chart 5: Top 10 Electric Vehicle Manufacturers by Market Share
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
import matplotlib.pyplot as plt

# Data for the bar plot
fig, ax = plt.subplots(figsize=(10, 10))  # Adjust the width and height as needed
make_counts = data_df['Make'].value_counts().head(10)  # Get the top 10 manufacturers

# Plotting a horizontal bar plot
make_counts.plot(kind='barh', ax=ax, color="orange")

# Set title and labels
ax.set_title('Top 10 Electric Vehicle Manufacturers by Market Share')
ax.set_xlabel('Number of Vehicles')
ax.set_ylabel('Manufacturer')

# Invert the y-axis to show the largest values at the top
ax.invert_yaxis()

plt.show()

# %% [markdown]
# **Insight**
#
# 1. Tesla is by far the largest player in the electric vehicle market, with more than 80,000 vehicles represented in this dataset.The dominance of Tesla suggests intense competition for other manufacturers. To gain market share, other companies will need to differentiate their products, improve their offerings, and invest in research and development.
#
# 2. The next closest competitors are Chevrolet and Nissan, each contributing a smaller yet notable share of the electric vehicle market.
# 3. Manufacturers like Ford, Kia, and BMW are part of the mid-range group, contributing around 10,000 to 20,000 vehicles each.
# 4. The chart provides a clear visualization of the uneven market share in electric vehicles, with Tesla significantly ahead of the competition.
#
# Understanding consumer preferences for electric vehicles is crucial for manufacturers. Factors such as range, price, charging infrastructure, and brand reputation will influence purchasing decisions.

# %% [markdown]
# # Chart 6: Base MSRP vs Electric Range
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
import matplotlib.pyplot as plt

# Create the scatter plot
ax = data_df.plot.scatter(x='Base MSRP', y='Electric Range', title='Base MSRP vs Electric Range')

# Add a grid to the plot
ax.grid(True)

# Display the plot
plt.show()

# %% [markdown]
# **Insight**
#
# 1. There's a clear positive correlation between Base MSRP and Electric Range. This indicates that as the electric range of a vehicle increases, its base MSRP tends to increase as well. This suggests that manufacturers are charging a premium for vehicles with longer range capabilities.
#
# 2. The overall trend of higher MSRPs for longer ranges suggests that advancements in battery technology and electric vehicle components are driving up costs.
#
# 3. The data points tend to cluster in specific regions. There are clusters of vehicles with lower MSRPs and shorter ranges, as well as clusters with higher MSRPs and longer ranges. This might suggest different market segments or pricing strategies.

# %% [markdown]
# # Chart 7: Correlation Heatmap Between Electric Range, Base MSRP and Model Year
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'data_df' is your DataFrame

# Create the figure with increased size
plt.figure(figsize=(9, 5))  # Set the figure size to 9x5 inches

# Create the heatmap
sns.heatmap(data_df[['Electric Range', 'Base MSRP', 'Model Year']].corr(), annot=True, cmap='coolwarm', fmt='.2f')

# Add title
plt.title('Correlation Heatmap', fontsize=16)

# Show the plot
plt.tight_layout()  # Adjust layout to fit the figure size
plt.show()

# %% [markdown]
# **1.Electric Range and Base MSRP:** There's a strong positive correlation between these two variables. This suggests that as the electric range of a vehicle increases, its base MSRP tends to increase as well. This could be due to factors like larger battery capacity, more advanced technology, and higher production costs.
#
# **2. Electric Range and Model Year:** There's a moderate negative correlation between these variables. This indicates that, on average, older models might have lower electric ranges compared to newer models. This could be attributed to advancements in battery technology and efficiency over time.
#
# **3. Base MSRP and Model Year:** There's a weak negative correlation between these variables. While there might be a slight tendency for older models to have lower base MSRPs, this relationship is not as strong as the one between Electric Range and Base MSRP.

# %% [markdown]
# # Chart 8: Distribution of Base MSRP by Electric Vehicle Type
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'data_df' is your DataFrame

# Create the figure with increased size
plt.figure(figsize=(12, 8))  # Set the figure size to 12x8 inches

# Create the boxplot
sns.boxplot(x='Electric Vehicle Type', y='Base MSRP', data=data_df)

# Add title and labels
plt.title('Distribution of Base MSRP by Electric Vehicle Type', fontsize=16)
plt.xlabel('Electric Vehicle Type', fontsize=14)
plt.ylabel('Base MSRP', fontsize=14)

# Rotate x-axis labels for better readability (if necessary)
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()  # Adjust layout to fit the figure size
plt.show()

# %% [markdown]
# **Insight**
#
# 1. The median MSRP for BEVs is slightly higher than that for PHEVs. This suggests that, on average, BEVs tend to have higher base prices compared to PHEVs. This might suggest different market segments targeting various price points and consumer preferences.
#
# 2. The presence of outliers, especially for PHEVs, might be associated with vehicles equipped with advanced features or higher-capacity batteries. These vehicles could be priced at a premium.

# %% [markdown]
# # Chart 9: Electric Vehicle Range Distribution
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Example data (replace this with your actual data)
# data_df = your_dataframe_here

# Create the figure with increased size
plt.figure(figsize=(12, 8))  # Set the figure size to 12x8 inches

# Create the histogram
data_df['Electric Range'].plot(kind='hist', bins=30, title='Electric Vehicle Range Distribution', edgecolor='black')

# Add labels for clarity
plt.xlabel('Electric Range (miles)', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

# Display the plot
plt.tight_layout()  # Adjust layout to fit the figure size
plt.show()

# %% [markdown]
# **Insight**
#
# 1. The highest frequency occurs at lower ranges, suggesting that the majority of electric vehicles on the market have a range between 0 and 50 miles.
#
# 2. Decreasing Frequency: As the range increases, the frequency of vehicles decreases, forming a downward sloping curve. This indicates that there are fewer vehicles with longer ranges.This show that the market is currently focused on shorter-range electric vehicles. This might be due to factors such as battery technology limitations, charging infrastructure constraints, and consumer preferences
#
# 3. Understanding consumer preferences for electric vehicle range is important for manufacturers and policymakers. Factors such as daily commute distance, charging accessibility, and vehicle price will influence consumer choices.

# %% [markdown]
# # Chart 10: Top 10 City by Electric Vehicle Adoption

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset

# Group by state to count the number of vehicles per state
ev_by_state = data_df.groupby('City')['VIN (1-10)'].count().sort_values(ascending=False)

# Plotting the top 10 states with the highest EV adoption
ev_by_state.head(10).plot(kind='bar', figsize=(10, 6), color='skyblue')

# Add chart title and labels
plt.title('Top 10 City by Electric Vehicle Adoption')
plt.xlabel('City')
plt.ylabel('Number of Vehicles')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Insight**
#
# 1. Seattle clearly leads the way in electric vehicle adoption, with a significantly higher number of vehicles compared to the other cities. This suggests that Seattle has created a favorable environment for electric vehicle adoption, possibly through policies, infrastructure, or consumer awareness.
#
# 2. Several cities Bellevue, Redmond, Vancouver, Bothell, Kirkland, and Sammamish, rank among the top 10. This indicates a strong concentration of electric vehicle adoption in this area, possibly due to factors like technology hubs, progressive policies, or higher incomes.
# 3. The availability of charging infrastructure and public transportation options could be influencing electric vehicle adoption in these cities. Assessing the infrastructure in these areas can identify factors contributing to their success.
#
# 4. Understanding consumer preferences in these cities can help identify factors driving electric vehicle adoption. Factors such as income levels, environmental awareness, and access to technology could be influencing the market.

# %% [markdown]
# # **Conclusion**
#
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# **Market Growth:** The electric vehicle market is experiencing significant growth, driven by factors such as advancements in technology, government policies, and increasing consumer awareness.
#
# **BEV Dominance:** Battery Electric Vehicles (BEVs) are currently dominating the market, with a higher market share compared to Plug-in Hybrid Electric Vehicles (PHEVs).
#
# **Price Premium for BEVs:** BEVs generally have higher base MSRPs compared to PHEVs, suggesting that manufacturers are charging a premium for fully electric vehicles.
#
# **Range and Pricing:** There's a strong positive correlation between electric vehicle range and base MSRP, indicating that consumers are willing to pay more for vehicles with longer range capabilities.
#
# **Government Policies:** Government policies, such as CAFV incentives, play a crucial role in driving EV adoption. However, the effectiveness of these policies can vary across regions.
#
# **Regional Variations:** Electric vehicle adoption rates differ across regions, with some cities and regions showing higher levels of adoption than others.

# %% [markdown]
# # **Recommendations**
#
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# **Policy Support:** Governments should continue to provide incentives and support for electric vehicle adoption, including tax credits, rebates, and infrastructure development.
#
# **Infrastructure Investment:** Investing in a robust charging infrastructure is essential for expanding the market for electric vehicles, particularly those with longer ranges.
#
# **Technological Advancements:** Continued research and development in battery technology, charging infrastructure, and vehicle range will be crucial for making electric vehicles more affordable, convenient, and appealing to consumers.
#
# **Consumer Education:** Raising consumer awareness about the benefits of electric vehicles and addressing concerns related to range, charging, and cost is important for driving adoption.
#
# **Targeted Policies:** Governments can tailor policies to specific regions or demographics to address regional variations and target populations with higher potential for EV adoption.
#
# **Collaboration:** Collaboration between governments, industry, and research institutions can accelerate the development and deployment of electric vehicle technologies and infrastructure.
#
# **Global Cooperation:** International cooperation can facilitate the sharing of knowledge, best practices, and standards related to electric vehicles, promoting global adoption and reducing barriers to trade.
